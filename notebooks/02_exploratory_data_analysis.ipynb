# %% [markdown]
# <div style="display: flex; flex-direction: row; justify-content: space-between; font-weight: bold; text-decoration: none">
# <a href="01_data_cleaning.ipynb"><<< Back to Data Cleaning</a>
# <a href="03_insights_and_visualizations.ipynb">Up Next: Insights and Data Visualizations >>></a>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df = pd.read_csv('../data/cleaned/cleaned_data.csv')
df
# Out:
#           County         City State  Postal Code  Model Year       Make  \
# 0        Stevens     Colville    WA      99114.0        2012     NISSAN
# 1         Yakima       Yakima    WA      98903.0        2023     SUBARU
# 2           King      Seattle    WA      98122.0        2018     NISSAN
# 3         Kitsap      Poulsbo    WA      98370.0        2025        BMW
# 4       Thurston         Yelm    WA      98597.0        2015       FIAT
# ...          ...          ...   ...          ...         ...        ...
# 279775     Clark    Washougal    WA      98671.0        2024      HONDA
# 279776      King      Seattle    WA      98103.0        2019        BMW
# 279777      King    Sammamish    WA      98075.0        2026     RIVIAN
# 279778    Pierce  Bonney Lake    WA      98391.0        2026      TESLA
# 279779    Pierce       Graham    WA      98338.0        2024  CHEVROLET
#
#            Model   Electric Vehicle Type  \
# 0           LEAF  Battery Electric (BEV)
# 1       SOLTERRA  Battery Electric (BEV)
# 2           LEAF  Battery Electric (BEV)
# 3             X5   Plug-in Hybrid (PHEV)
# 4            500  Battery Electric (BEV)
# ...          ...                     ...
# 279775  PROLOGUE  Battery Electric (BEV)
# 279776        I3   Plug-in Hybrid (PHEV)
# 279777       R1S  Battery Electric (BEV)
# 279778   MODEL Y  Battery Electric (BEV)
# 279779    BLAZER  Battery Electric (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligible?  \
# 0                                                 True
# 1                                                  NaN
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ...                                                ...
# 279775                                             NaN
# 279776                                            True
# 279777                                             NaN
# 279778                                             NaN
# 279779                                             NaN
#
#         Electric Range (in Miles)             Vehicle Location  \
# 0                            73.0  POINT (-117.90454 48.54657)
# 1                             NaN  POINT (-120.71847 46.55029)
# 2                           151.0  POINT (-122.31009 47.60803)
# 3                            40.0  POINT (-122.64681 47.73689)
# 4                            87.0  POINT (-122.60735 46.94239)
# ...                           ...                          ...
# 279775                        NaN  POINT (-122.35341 45.57923)
# 279776                      126.0  POINT (-122.35436 47.67596)
# 279777                        NaN  POINT (-122.03539 47.61344)
# 279778                        NaN  POINT (-122.17144 47.19175)
# 279779                        NaN  POINT (-122.29477 47.05703)
#
#                                          Electric Utility  \
# 0                                             AVISTA CORP
# 1                                              PACIFICORP
# 2            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 3                                  PUGET SOUND ENERGY INC
# 4                                  PUGET SOUND ENERGY INC
# ...                                                   ...
# 279775  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...
# 279776       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 279777      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 279778      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 279779      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
#
#         WA Retail Gas Prices (Dollars per Gallon)
# 0                                           3.883
# 1                                           4.541
# 2                                           3.269
# 3                                           4.228
# 4                                           2.754
# ...                                           ...
# 279775                                      4.162
# 279776                                      3.186
# 279777                                        NaN
# 279778                                        NaN
# 279779                                      4.162
#
# [279780 rows x 13 columns]

# %% [markdown]
# #### Objectives / Questions

# %% [markdown]
# #### Exploratory Data Analysis

# %% [markdown]
# #### Brief Visual Analysis

# %% [markdown]
# <div style="display: flex; flex-direction: row; justify-content: space-between; font-weight: bold; text-decoration: none">
# <a href="01_data_cleaning.ipynb"><<< Back to Data Cleaning</a>
# <a href="03_insights_and_visualizations.ipynb">Up Next: Insights and Data Visualizations >>></a>
# </div>
